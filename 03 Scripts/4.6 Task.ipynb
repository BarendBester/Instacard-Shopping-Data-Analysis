# %% [markdown]
# 1. Task 4.6 Combining prodcts and order data sets

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
# create path for importing new data set
path = r'C:\Users\beatr\Documents\23-05-2023-Instacart Basket Analysis'

# %%
# 3. read the pickle file
df_merged_large = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# 4. check the shape of the imported data frame
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   2                  8                     NaN
# 2                   2                  8                     NaN
# 3                   2                  8                     NaN
# 4                   2                  8                     NaN
#
#    new_customer  product_id  add_to_cart_order  reordered _merge
# 0          True         196                  1          0   both
# 1          True       14084                  2          0   both
# ...

# %%
df_merged_large.shape
# Out:
# (32434489, 13)

# %% [markdown]
# 5. determine a way to combine data sets

# %%
# step 1 load other prepared data set
df_products_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# remove merge placeholder
del df_merged_large['_merge']
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   2                  8                     NaN
# 2                   2                  8                     NaN
# 3                   2                  8                     NaN
# 4                   2                  8                     NaN
#
#    new_customer  product_id  add_to_cart_order  reordered
# 0          True         196                  1          0
# 1          True       14084                  2          0
# ...

# %%
# join on product_id with standard inner join
df_orders_products_merged = df_merged_large.merge(df_products_checked, on = 'product_id', indicator = True)

# %% [markdown]
# 6. Confirm the results of the merge using the merge flag.

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0
#
#    new_customer  product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0          True         196                  1          0           195
# ...

# %%
df_orders_products_merged.shape
# Out:
# (32404859, 18)

# %%
df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#check with outer merge
df_orders_products_merged_outer = df_merged_large.merge(df_products_checked, on = 'product_id', how = 'outer', indicator = True)

# %%
df_orders_products_merged_outer.shape
df_orders_products_merged_outer['_merge'].value_counts()
# we have left_only        30200
# Out:
# both          32404859
# left_only        30200
# right_only          11
# Name: _merge, dtype: int64

# %% [markdown]
# 7. Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).

# %%
# export merged product order data set as pickle
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
