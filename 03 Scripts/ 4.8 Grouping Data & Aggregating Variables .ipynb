# %% [markdown]
# 1. Grouping Data

# %%
#import librariers
import pandas as pd
import numpy as np
import os

# %%
#create pathway for savingg and uploading datasets
path = r'C:\Users\beatr\Documents\23-05-2023-Instacart Basket Analysis'

# %%
#import dataset
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined_new.pkl'))

# %%
#check data set
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0
#
#    new_customer  product_id  ...  Unnamed: 0_y  product_name  aisle_id  \
# 0          True         196  ...           195          Soda        77
# 1         False         196  ...           195          Soda        77
# 2         False         196  ...           195          Soda        77
# 3         False         196  ...           195          Soda        77
# 4         False         196  ...           195          Soda        77
#
#   department_id  prices  _merge    price_range_loc     busiest_day  \
# 0             7     9.0    both  Mid-range product  Regularly busy
# 1             7     9.0    both  Mid-range product  Regularly busy
# 2             7     9.0    both  Mid-range product  Regularly busy
# 3             7     9.0    both  Mid-range product      Least busy
# 4             7     9.0    both  Mid-range product      Least busy
#
#          busiest_days busiest_period_of_day
# 0      Regularly busy        Average orders
# 1  Least busiest days        Average orders
# 2  Least busiest days           Most orders
# 3  Least busiest days        Average orders
# 4  Least busiest days           Most orders
#
# [5 rows x 22 columns]

# %%
# remove unamed column 1 and 2
del ords_prods_merge['Unnamed: 0.1']

# %%
del ords_prods_merge['Unnamed: 0_x']

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
# 5                    19.0         False         196                  1
# 6                    20.0         False         196                  1
# 7                    14.0         False         196                  2
# 8                     0.0         False         196                  4
# 9                    30.0         False         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# 0          0           195         Soda        77              7     9.0
# 1          1           195         Soda        77              7     9.0
# 2          1           195         Soda        77              7     9.0
# 3          1           195         Soda        77              7     9.0
# 4          1           195         Soda        77              7     9.0
# 5          1           195         Soda        77              7     9.0
# 6          1           195         Soda        77              7     9.0
# 7          1           195         Soda        77              7     9.0
# 8          1           195         Soda        77              7     9.0
# 9          1           195         Soda        77              7     9.0
#
#   _merge    price_range_loc     busiest_day        busiest_days  \
# 0   both  Mid-range product  Regularly busy      Regularly busy
# 1   both  Mid-range product  Regularly busy  Least busiest days
# 2   both  Mid-range product  Regularly busy  Least busiest days
# 3   both  Mid-range product      Least busy  Least busiest days
# 4   both  Mid-range product      Least busy  Least busiest days
# 5   both  Mid-range product  Regularly busy      Regularly busy
# 6   both  Mid-range product  Regularly busy        Busiest days
# 7   both  Mid-range product  Regularly busy        Busiest days
# 8   both  Mid-range product  Regularly busy        Busiest days
# 9   both  Mid-range product      Least busy  Least busiest days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2           Most orders
# 3        Average orders
# 4           Most orders
# 5        Average orders
# 6        Average orders
# 7           Most orders
# 8           Most orders
# 9        Average orders

# %%
#create subset
df = ords_prods_merge[:1000000]

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
# 5                    19.0         False         196                  1
# 6                    20.0         False         196                  1
# 7                    14.0         False         196                  2
# 8                     0.0         False         196                  4
# 9                    30.0         False         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# 0          0           195         Soda        77              7     9.0
# 1          1           195         Soda        77              7     9.0
# 2          1           195         Soda        77              7     9.0
# 3          1           195         Soda        77              7     9.0
# 4          1           195         Soda        77              7     9.0
# 5          1           195         Soda        77              7     9.0
# 6          1           195         Soda        77              7     9.0
# 7          1           195         Soda        77              7     9.0
# 8          1           195         Soda        77              7     9.0
# 9          1           195         Soda        77              7     9.0
#
#   _merge    price_range_loc     busiest_day        busiest_days  \
# 0   both  Mid-range product  Regularly busy      Regularly busy
# 1   both  Mid-range product  Regularly busy  Least busiest days
# 2   both  Mid-range product  Regularly busy  Least busiest days
# 3   both  Mid-range product      Least busy  Least busiest days
# 4   both  Mid-range product      Least busy  Least busiest days
# 5   both  Mid-range product  Regularly busy      Regularly busy
# 6   both  Mid-range product  Regularly busy        Busiest days
# 7   both  Mid-range product  Regularly busy        Busiest days
# 8   both  Mid-range product  Regularly busy        Busiest days
# 9   both  Mid-range product      Least busy  Least busiest days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2           Most orders
# 3        Average orders
# 4           Most orders
# 5        Average orders
# 6        Average orders
# 7           Most orders
# 8           Most orders
# 9        Average orders

# %% [markdown]
# 1. Grouping Data with pandas

# %%
# How to use the group by function with pandas
df.groupby('product_name')

# %%
#Performing a Single Aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# do the same with the mean function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
#Performing a multiple  Aggregation
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# 2. Aggregating Data with transform()

# %%
#Split the data into groups based on the “user_id” column.
#Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
#Create a new column, “max_order,” into which you’ll place the results of your aggregation.
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
# 5                    19.0         False         196                  1
# 6                    20.0         False         196                  1
# 7                    14.0         False         196                  2
# 8                     0.0         False         196                  4
# 9                    30.0         False         196                  1
#
#    reordered  ...  product_name aisle_id  department_id  prices  _merge  \
# 0          0  ...          Soda       77              7     9.0    both
# 1          1  ...          Soda       77              7     9.0    both
# 2          1  ...          Soda       77              7     9.0    both
# 3          1  ...          Soda       77              7     9.0    both
# 4          1  ...          Soda       77              7     9.0    both
# 5          1  ...          Soda       77              7     9.0    both
# 6          1  ...          Soda       77              7     9.0    both
# 7          1  ...          Soda       77              7     9.0    both
# 8          1  ...          Soda       77              7     9.0    both
# 9          1  ...          Soda       77              7     9.0    both
#
#      price_range_loc     busiest_day        busiest_days  \
# 0  Mid-range product  Regularly busy      Regularly busy
# 1  Mid-range product  Regularly busy  Least busiest days
# 2  Mid-range product  Regularly busy  Least busiest days
# 3  Mid-range product      Least busy  Least busiest days
# 4  Mid-range product      Least busy  Least busiest days
# 5  Mid-range product  Regularly busy      Regularly busy
# 6  Mid-range product  Regularly busy        Busiest days
# 7  Mid-range product  Regularly busy        Busiest days
# 8  Mid-range product  Regularly busy        Busiest days
# 9  Mid-range product      Least busy  Least busiest days
#
#   busiest_period_of_day max_order
# 0        Average orders        10
# 1        Average orders        10
# 2           Most orders        10
# 3        Average orders        10
# 4           Most orders        10
# 5        Average orders        10
# 6        Average orders        10
# 7           Most orders        10
# 8           Most orders        10
# 9        Average orders        10
#
# [10 rows x 21 columns]

# %%
# No max display
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
# 20   2231262       31            17                   3                 11
# 21   2580647       43             6                   4                 16
# 22   2187180       43             9                   4                 12
# 23   2497897       52             1                   1                  9
# 24   1318871       52             2                   1                 10
# 25   1261384       52             3                   1                 10
# 26    580568       52             5                   2                 10
# 27   2428073       52             7                   2                  7
# 28    342306       52             9                   1                 11
# 29   1520353       52            10                   2                 10
# 30   2542086       52            11                   2                  9
# 31    944694       52            12                   1                 16
# 32   1268191       52            15                   2                 11
# 33   1122089       52            17                   2                 10
# 34   1498922       52            18                   2                 10
# 35    180919       52            19                   3                  8
# 36   2695875       52            21                   5                 10
# 37   3205960       67             1                   3                 11
# 38    970922       67             2                   1                 15
# 39    596585       67             3                   1                 13
# 40   2037087       67             4                   2                  9
# 41   2474111       67             5                   3                 14
# 42   1568481       67             6                   3                 12
# 43   2048527       67             8                   2                 11
# 44   2389031       67             9                   2                 14
# 45   2378562       67            10                   1                 10
# 46   1515698       67            11                   1                 11
# 47   1928050       67            12                   2                 12
# 48   1949274       67            13                   1                 10
# 49    551869       67            14                   1                  9
# 50    768572       67            16                   4                 10
# 51    150528       67            18                   5                 16
# 52     29758       67            19                   0                 14
# 53   1558976       67            21                   1                  9
# 54    863974       67            22                   1                 11
# 55   2308399       67            23                   1                 14
# 56   2759128       81             3                   1                  9
# 57   1812985       81             5                   2                 20
# 58   1889835       82             1                   3                 15
# 59    499460       82             3                   5                 10
# 60   2728456       82             4                   0                 11
# 61   2653743       82             6                   4                  9
# 62   1358880       82             9                   1                 10
# 63    343588       82            10                   2                 11
# 64   3034663       82            15                   2                 11
# 65    147262       82            18                   1                 13
# 66   3144004       82            19                   2                 15
# 67   2126069       98             3                   0                  9
# 68   2210120       98             7                   5                 14
# 69    681011       98             9                   3                  9
# 70   2846344       98            11                   4                 13
# 71    747431       98            12                   6                 13
# 72   2383054       98            13                   4                 11
# 73   1993729       98            14                   5                  8
# 74   1403849      109             3                   3                 17
# 75    520620      120             1                   3                 11
# 76   3273029      120             3                   2                  8
# 77   1861943      185             2                   1                 12
# 78   2040988      195             1                   1                 14
# 79   1680569      195             8                   1                  9
# 80    276171      195            19                   5                 11
# 81   2744976      195            22                   5                 10
# 82   2781919      195            25                   1                 14
# 83   1738718      195            31                   2                  8
# 84   3058369      195            34                   3                 10
# 85   1485596      195            37                   2                 15
# 86    417035      195            40                   3                 16
# 87   1615297      195            47                   5                 10
# 88   1765587      195            52                   3                 12
# 89    745908      195            57                   4                 11
# 90   2505656      222            17                   2                 12
# 91   3268370      222            38                   5                 15
# 92   2016711      290             9                   5                 19
# 93   2706088      290            28                   6                 10
# 94   1952286      331             6                   5                 16
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True         196                  1
# 1                     15.0         False         196                  1
# 2                     21.0         False         196                  1
# 3                     29.0         False         196                  1
# 4                     28.0         False         196                  1
# 5                     19.0         False         196                  1
# 6                     20.0         False         196                  1
# 7                     14.0         False         196                  2
# 8                      0.0         False         196                  4
# 9                     30.0         False         196                  1
# 10                     7.0         False         196                  2
# 11                     8.0         False         196                  6
# 12                     7.0         False         196                  1
# 13                     7.0         False         196                  1
# 14                    14.0         False         196                  1
# 15                     6.0         False         196                  3
# 16                     8.0         False         196                 15
# 17                     6.0         False         196                  1
# 18                     6.0         False         196                  2
# 19                     7.0         False         196                 17
# 20                     8.0         False         196                 14
# 21                     4.0         False         196                  9
# 22                     3.0         False         196                  1
# 23                     NaN          True         196                  4
# 24                     7.0         False         196                  5
# 25                     7.0         False         196                  3
# 26                     8.0         False         196                  6
# 27                     8.0         False         196                  5
# 28                     7.0         False         196                  5
# 29                     8.0         False         196                  4
# 30                     7.0         False         196                  3
# 31                     6.0         False         196                  7
# 32                     8.0         False         196                  3
# 33                     6.0         False         196                  4
# 34                    14.0         False         196                  6
# 35                     8.0         False         196                  4
# 36                    30.0         False         196                  1
# 37                     NaN          True         196                  1
# 38                     5.0         False         196                  2
# 39                     7.0         False         196                  2
# 40                     8.0         False         196                  1
# 41                     8.0         False         196                  2
# 42                     7.0         False         196                  2
# 43                     7.0         False         196                  1
# 44                     7.0         False         196                  1
# 45                     6.0         False         196                  1
# 46                     7.0         False         196                  1
# 47                     8.0         False         196                  1
# 48                     6.0         False         196                  1
# 49                     7.0         False         196                  1
# 50                     9.0         False         196                  1
# 51                     4.0         False         196                  1
# 52                     9.0         False         196                  2
# 53                     5.0         False         196                  2
# 54                    14.0         False         196                  3
# 55                    14.0         False         196                  1
# 56                    14.0         False         196                  2
# 57                    30.0         False         196                  1
# 58                     NaN          True         196                  6
# 59                     5.0         False         196                  2
# 60                    16.0         False         196                  1
# 61                    13.0         False         196                  5
# 62                    30.0         False         196                  1
# 63                     1.0         False         196                  1
# 64                    12.0         False         196                  1
# 65                     7.0         False         196                  1
# 66                     8.0         False         196                  1
# 67                    25.0         False         196                  7
# 68                     5.0         False         196                  1
# 69                    30.0         False         196                  1
# 70                    15.0         False         196                  2
# 71                    30.0         False         196                  4
# 72                    30.0         False         196                  1
# 73                     8.0         False         196                  2
# 74                     9.0         False         196                  5
# 75                     NaN          True         196                  2
# 76                    19.0         False         196                  2
# 77                    25.0         False         196                 10
# 78                     NaN          True         196                  2
# 79                     4.0         False         196                  2
# 80                     3.0         False         196                  2
# 81                     7.0         False         196                  2
# 82                     4.0         False         196                  1
# 83                     4.0         False         196                  2
# 84                     6.0         False         196                  2
# 85                     0.0         False         196                  2
# 86                     2.0         False         196                  2
# 87                     2.0         False         196                  2
# 88                     2.0         False         196                  3
# 89                     3.0         False         196                  3
# 90                     1.0         False         196                  2
# 91                     1.0         False         196                  6
# 92                     6.0         False         196                  8
# 93                     7.0         False         196                 16
# 94                    30.0         False         196                  8
# 95                     NaN          True         196                  1
# 96                     3.0         False         196                  9
# 97                    22.0         False         196                  3
# 98                    30.0         False         196                  2
# 99                    16.0         False         196                  2
#
#     reordered  ...  product_name aisle_id  department_id  prices  _merge  \
# 0           0  ...          Soda       77              7     9.0    both
# 1           1  ...          Soda       77              7     9.0    both
# 2           1  ...          Soda       77              7     9.0    both
# 3           1  ...          Soda       77              7     9.0    both
# 4           1  ...          Soda       77              7     9.0    both
# 5           1  ...          Soda       77              7     9.0    both
# 6           1  ...          Soda       77              7     9.0    both
# 7           1  ...          Soda       77              7     9.0    both
# 8           1  ...          Soda       77              7     9.0    both
# 9           1  ...          Soda       77              7     9.0    both
# 10          0  ...          Soda       77              7     9.0    both
# 11          1  ...          Soda       77              7     9.0    both
# 12          1  ...          Soda       77              7     9.0    both
# 13          1  ...          Soda       77              7     9.0    both
# 14          1  ...          Soda       77              7     9.0    both
# 15          0  ...          Soda       77              7     9.0    both
# 16          1  ...          Soda       77              7     9.0    both
# 17          1  ...          Soda       77              7     9.0    both
# 18          0  ...          Soda       77              7     9.0    both
# 19          0  ...          Soda       77              7     9.0    both
# 20          1  ...          Soda       77              7     9.0    both
# 21          0  ...          Soda       77              7     9.0    both
# 22          1  ...          Soda       77              7     9.0    both
# 23          0  ...          Soda       77              7     9.0    both
# 24          1  ...          Soda       77              7     9.0    both
# 25          1  ...          Soda       77              7     9.0    both
# 26          1  ...          Soda       77              7     9.0    both
# 27          1  ...          Soda       77              7     9.0    both
# 28          1  ...          Soda       77              7     9.0    both
# 29          1  ...          Soda       77              7     9.0    both
# 30          1  ...          Soda       77              7     9.0    both
# 31          1  ...          Soda       77              7     9.0    both
# 32          1  ...          Soda       77              7     9.0    both
# 33          1  ...          Soda       77              7     9.0    both
# 34          1  ...          Soda       77              7     9.0    both
# 35          1  ...          Soda       77              7     9.0    both
# 36          1  ...          Soda       77              7     9.0    both
# 37          0  ...          Soda       77              7     9.0    both
# 38          1  ...          Soda       77              7     9.0    both
# 39          1  ...          Soda       77              7     9.0    both
# 40          1  ...          Soda       77              7     9.0    both
# 41          1  ...          Soda       77              7     9.0    both
# 42          1  ...          Soda       77              7     9.0    both
# 43          1  ...          Soda       77              7     9.0    both
# 44          1  ...          Soda       77              7     9.0    both
# 45          1  ...          Soda       77              7     9.0    both
# 46          1  ...          Soda       77              7     9.0    both
# 47          1  ...          Soda       77              7     9.0    both
# 48          1  ...          Soda       77              7     9.0    both
# 49          1  ...          Soda       77              7     9.0    both
# 50          1  ...          Soda       77              7     9.0    both
# 51          1  ...          Soda       77              7     9.0    both
# 52          1  ...          Soda       77              7     9.0    both
# 53          1  ...          Soda       77              7     9.0    both
# 54          1  ...          Soda       77              7     9.0    both
# 55          1  ...          Soda       77              7     9.0    both
# 56          0  ...          Soda       77              7     9.0    both
# 57          1  ...          Soda       77              7     9.0    both
# 58          0  ...          Soda       77              7     9.0    both
# 59          1  ...          Soda       77              7     9.0    both
# 60          1  ...          Soda       77              7     9.0    both
# 61          1  ...          Soda       77              7     9.0    both
# 62          1  ...          Soda       77              7     9.0    both
# 63          1  ...          Soda       77              7     9.0    both
# 64          1  ...          Soda       77              7     9.0    both
# 65          1  ...          Soda       77              7     9.0    both
# 66          1  ...          Soda       77              7     9.0    both
# 67          0  ...          Soda       77              7     9.0    both
# 68          1  ...          Soda       77              7     9.0    both
# 69          1  ...          Soda       77              7     9.0    both
# 70          1  ...          Soda       77              7     9.0    both
# 71          1  ...          Soda       77              7     9.0    both
# 72          1  ...          Soda       77              7     9.0    both
# 73          1  ...          Soda       77              7     9.0    both
# 74          0  ...          Soda       77              7     9.0    both
# 75          0  ...          Soda       77              7     9.0    both
# 76          1  ...          Soda       77              7     9.0    both
# 77          0  ...          Soda       77              7     9.0    both
# 78          0  ...          Soda       77              7     9.0    both
# 79          1  ...          Soda       77              7     9.0    both
# 80          1  ...          Soda       77              7     9.0    both
# 81          1  ...          Soda       77              7     9.0    both
# 82          1  ...          Soda       77              7     9.0    both
# 83          1  ...          Soda       77              7     9.0    both
# 84          1  ...          Soda       77              7     9.0    both
# 85          1  ...          Soda       77              7     9.0    both
# 86          1  ...          Soda       77              7     9.0    both
# 87          1  ...          Soda       77              7     9.0    both
# 88          1  ...          Soda       77              7     9.0    both
# 89          1  ...          Soda       77              7     9.0    both
# 90          0  ...          Soda       77              7     9.0    both
# 91          1  ...          Soda       77              7     9.0    both
# 92          0  ...          Soda       77              7     9.0    both
# 93          1  ...          Soda       77              7     9.0    both
# 94          0  ...          Soda       77              7     9.0    both
# 95          0  ...          Soda       77              7     9.0    both
# 96          0  ...          Soda       77              7     9.0    both
# 97          0  ...          Soda       77              7     9.0    both
# 98          0  ...          Soda       77              7     9.0    both
# 99          1  ...          Soda       77              7     9.0    both
#
#       price_range_loc     busiest_day        busiest_days  \
# 0   Mid-range product  Regularly busy      Regularly busy
# 1   Mid-range product  Regularly busy  Least busiest days
# 2   Mid-range product  Regularly busy  Least busiest days
# 3   Mid-range product      Least busy  Least busiest days
# 4   Mid-range product      Least busy  Least busiest days
# 5   Mid-range product  Regularly busy      Regularly busy
# 6   Mid-range product  Regularly busy        Busiest days
# 7   Mid-range product  Regularly busy        Busiest days
# 8   Mid-range product  Regularly busy        Busiest days
# 9   Mid-range product      Least busy  Least busiest days
# 10  Mid-range product  Regularly busy        Busiest days
# 11  Mid-range product  Regularly busy      Regularly busy
# 12  Mid-range product  Regularly busy      Regularly busy
# 13  Mid-range product  Regularly busy        Busiest days
# 14  Mid-range product  Regularly busy        Busiest days
# 15  Mid-range product  Regularly busy      Regularly busy
# 16  Mid-range product  Regularly busy      Regularly busy
# 17  Mid-range product      Least busy  Least busiest days
# 18  Mid-range product  Regularly busy  Least busiest days
# 19  Mid-range product  Regularly busy  Least busiest days
# 20  Mid-range product  Regularly busy  Least busiest days
# 21  Mid-range product      Least busy  Least busiest days
# 22  Mid-range product      Least busy  Least busiest days
# 23  Mid-range product  Regularly busy        Busiest days
# 24  Mid-range product  Regularly busy        Busiest days
# 25  Mid-range product  Regularly busy        Busiest days
# 26  Mid-range product  Regularly busy      Regularly busy
# 27  Mid-range product  Regularly busy      Regularly busy
# 28  Mid-range product  Regularly busy        Busiest days
# 29  Mid-range product  Regularly busy      Regularly busy
# 30  Mid-range product  Regularly busy      Regularly busy
# 31  Mid-range product  Regularly busy        Busiest days
# 32  Mid-range product  Regularly busy      Regularly busy
# 33  Mid-range product  Regularly busy      Regularly busy
# 34  Mid-range product  Regularly busy      Regularly busy
# 35  Mid-range product  Regularly busy  Least busiest days
# 36  Mid-range product  Regularly busy      Regularly busy
# 37  Mid-range product  Regularly busy  Least busiest days
# 38  Mid-range product  Regularly busy        Busiest days
# 39  Mid-range product  Regularly busy        Busiest days
# 40  Mid-range product  Regularly busy      Regularly busy
# 41  Mid-range product  Regularly busy  Least busiest days
# 42  Mid-range product  Regularly busy  Least busiest days
# 43  Mid-range product  Regularly busy      Regularly busy
# 44  Mid-range product  Regularly busy      Regularly busy
# 45  Mid-range product  Regularly busy        Busiest days
# 46  Mid-range product  Regularly busy        Busiest days
# 47  Mid-range product  Regularly busy      Regularly busy
# 48  Mid-range product  Regularly busy        Busiest days
# 49  Mid-range product  Regularly busy        Busiest days
# 50  Mid-range product      Least busy  Least busiest days
# 51  Mid-range product  Regularly busy      Regularly busy
# 52  Mid-range product     Busiest day        Busiest days
# 53  Mid-range product  Regularly busy        Busiest days
# 54  Mid-range product  Regularly busy        Busiest days
# 55  Mid-range product  Regularly busy        Busiest days
# 56  Mid-range product  Regularly busy        Busiest days
# 57  Mid-range product  Regularly busy      Regularly busy
# 58  Mid-range product  Regularly busy  Least busiest days
# 59  Mid-range product  Regularly busy      Regularly busy
# 60  Mid-range product     Busiest day        Busiest days
# 61  Mid-range product      Least busy  Least busiest days
# 62  Mid-range product  Regularly busy        Busiest days
# 63  Mid-range product  Regularly busy      Regularly busy
# 64  Mid-range product  Regularly busy      Regularly busy
# 65  Mid-range product  Regularly busy        Busiest days
# 66  Mid-range product  Regularly busy      Regularly busy
# 67  Mid-range product     Busiest day        Busiest days
# 68  Mid-range product  Regularly busy      Regularly busy
# 69  Mid-range product  Regularly busy  Least busiest days
# 70  Mid-range product      Least busy  Least busiest days
# 71  Mid-range product  Regularly busy      Regularly busy
# 72  Mid-range product      Least busy  Least busiest days
# 73  Mid-range product  Regularly busy      Regularly busy
# 74  Mid-range product  Regularly busy  Least busiest days
# 75  Mid-range product  Regularly busy  Least busiest days
# 76  Mid-range product  Regularly busy      Regularly busy
# 77  Mid-range product  Regularly busy        Busiest days
# 78  Mid-range product  Regularly busy        Busiest days
# 79  Mid-range product  Regularly busy        Busiest days
# 80  Mid-range product  Regularly busy      Regularly busy
# 81  Mid-range product  Regularly busy      Regularly busy
# 82  Mid-range product  Regularly busy        Busiest days
# 83  Mid-range product  Regularly busy      Regularly busy
# 84  Mid-range product  Regularly busy  Least busiest days
# 85  Mid-range product  Regularly busy      Regularly busy
# 86  Mid-range product  Regularly busy  Least busiest days
# 87  Mid-range product  Regularly busy      Regularly busy
# 88  Mid-range product  Regularly busy  Least busiest days
# 89  Mid-range product      Least busy  Least busiest days
# 90  Mid-range product  Regularly busy      Regularly busy
# 91  Mid-range product  Regularly busy      Regularly busy
# 92  Mid-range product  Regularly busy      Regularly busy
# 93  Mid-range product  Regularly busy      Regularly busy
# 94  Mid-range product  Regularly busy      Regularly busy
# 95  Mid-range product  Regularly busy      Regularly busy
# 96  Mid-range product  Regularly busy      Regularly busy
# 97  Mid-range product      Least busy  Least busiest days
# 98  Mid-range product  Regularly busy        Busiest days
# 99  Mid-range product  Regularly busy  Least busiest days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2            Most orders        10
# 3         Average orders        10
# 4            Most orders        10
# 5         Average orders        10
# 6         Average orders        10
# 7            Most orders        10
# 8            Most orders        10
# 9         Average orders        10
# 10        Average orders        22
# 11           Most orders        22
# 12           Most orders        22
# 13        Average orders        22
# 14           Most orders        22
# 15           Most orders         9
# 16           Most orders         9
# 17        Average orders         9
# 18           Most orders        33
# 19        Average orders        20
# 20           Most orders        20
# 21           Most orders        11
# 22           Most orders        11
# 23        Average orders        27
# 24           Most orders        27
# 25           Most orders        27
# 26           Most orders        27
# 27        Average orders        27
# 28           Most orders        27
# 29           Most orders        27
# 30        Average orders        27
# 31           Most orders        27
# 32           Most orders        27
# 33           Most orders        27
# 34           Most orders        27
# 35        Average orders        27
# 36           Most orders        27
# 37           Most orders        24
# 38           Most orders        24
# 39           Most orders        24
# 40        Average orders        24
# 41           Most orders        24
# 42           Most orders        24
# 43           Most orders        24
# 44           Most orders        24
# 45           Most orders        24
# 46           Most orders        24
# 47           Most orders        24
# 48           Most orders        24
# 49        Average orders        24
# 50           Most orders        24
# 51           Most orders        24
# 52           Most orders        24
# 53        Average orders        24
# 54           Most orders        24
# 55           Most orders        24
# 56        Average orders         7
# 57        Average orders         7
# 58           Most orders        19
# 59           Most orders        19
# 60           Most orders        19
# 61        Average orders        19
# 62           Most orders        19
# 63           Most orders        19
# 64           Most orders        19
# 65           Most orders        19
# 66           Most orders        19
# 67        Average orders        14
# 68           Most orders        14
# 69        Average orders        14
# 70           Most orders        14
# 71           Most orders        14
# 72           Most orders        14
# 73        Average orders        14
# 74        Average orders         6
# 75           Most orders         3
# 76        Average orders         3
# 77           Most orders         6
# 78           Most orders        58
# 79        Average orders        58
# 80           Most orders        58
# 81           Most orders        58
# 82           Most orders        58
# 83        Average orders        58
# 84           Most orders        58
# 85           Most orders        58
# 86           Most orders        58
# 87           Most orders        58
# 88           Most orders        58
# 89           Most orders        58
# 90           Most orders        70
# 91           Most orders        70
# 92        Average orders        51
# 93           Most orders        51
# 94           Most orders         8
# 95           Most orders         3
# 96        Average orders         3
# 97           Most orders         8
# 98        Average orders        22
# 99        Average orders        22
#
# [100 rows x 21 columns]

# %%
#use loc function to assign loyalty
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
#use loc function to assign average
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
#use loc function to assign new customer
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#use valuecounts function to check loyalty of customers
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#check head
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
# 5                    19.0         False         196                  1
# 6                    20.0         False         196                  1
# 7                    14.0         False         196                  2
# 8                     0.0         False         196                  4
# 9                    30.0         False         196                  1
#
#    reordered  ...  aisle_id department_id  prices  _merge    price_range_loc  \
# 0          0  ...        77             7     9.0    both  Mid-range product
# 1          1  ...        77             7     9.0    both  Mid-range product
# 2          1  ...        77             7     9.0    both  Mid-range product
# 3          1  ...        77             7     9.0    both  Mid-range product
# 4          1  ...        77             7     9.0    both  Mid-range product
# 5          1  ...        77             7     9.0    both  Mid-range product
# 6          1  ...        77             7     9.0    both  Mid-range product
# 7          1  ...        77             7     9.0    both  Mid-range product
# 8          1  ...        77             7     9.0    both  Mid-range product
# 9          1  ...        77             7     9.0    both  Mid-range product
#
#       busiest_day        busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy      Regularly busy        Average orders        10
# 1  Regularly busy  Least busiest days        Average orders        10
# 2  Regularly busy  Least busiest days           Most orders        10
# 3      Least busy  Least busiest days        Average orders        10
# 4      Least busy  Least busiest days           Most orders        10
# 5  Regularly busy      Regularly busy        Average orders        10
# 6  Regularly busy        Busiest days        Average orders        10
# 7  Regularly busy        Busiest days           Most orders        10
# 8  Regularly busy        Busiest days           Most orders        10
# 9      Least busy  Least busiest days        Average orders        10
#
#    loyalty_flag
# 0  New customer
# 1  New customer
# 2  New customer
# 3  New customer
# 4  New customer
# 5  New customer
# 6  New customer
# 7  New customer
# 8  New customer
# 9  New customer
#
# [10 rows x 22 columns]

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(5)
#
# NameError: name 'ords_prods_merge' is not defined
